# %% [markdown]
# # Country of birth for people granted New Zealand Citizenship

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('granted-citizenship-1949-2020.csv')
df
# Out:
#     Country of Birth   Total        %     1949   1950   1951   1952   1953  \
# 0               Aden      25    0.00%      NaN    NaN    NaN    NaN    NaN
# 1        Afghanistan    3683    0.40%      NaN    NaN    NaN    NaN    NaN
# 2            Albania     145    0.02%      NaN    NaN    NaN    NaN    NaN
# 3            Algeria     247    0.03%      NaN    NaN    NaN    NaN    NaN
# 4     American Samoa     877    0.09%      NaN    NaN    NaN    NaN    NaN
# ..               ...     ...      ...      ...    ...    ...    ...    ...
# 330            Zaire      25    0.00%      1.0    NaN    NaN    NaN    NaN
# 331           Zambia    1449    0.16%      NaN    NaN    NaN    NaN    NaN
# 332         Zanzibar       3    0.00%      NaN    NaN    NaN    NaN    NaN
# 333         Zimbabwe    8400    0.90%      NaN    NaN    NaN    NaN    NaN
# 334            TOTAL  930666  100.00%  18629.0  230.0  369.0  388.0  390.0
#
# ...

# %%
df.describe()
# Out:
#                Total          1949        1950        1951        1952  \
# count     335.000000    118.000000   40.000000   48.000000   46.000000
# mean     5556.214925    315.745763   11.500000   15.375000   16.869565
# std     52264.094246   1947.403330   36.237818   53.615901   58.568330
# min         1.000000      1.000000    1.000000    1.000000    1.000000
# 25%        10.000000      1.000000    1.000000    2.000000    1.000000
# 50%       100.000000      3.000000    3.000000    3.500000    3.000000
# 75%       774.000000     13.750000    6.500000   11.000000   10.000000
# max    930666.000000  18629.000000  230.000000  369.000000  388.000000
#
#              1953        1954        1955         1956         1957  ...  \
# count   51.000000   60.000000   62.000000    66.000000    68.000000  ...
# mean    15.294118   21.033333   25.741935    34.212121    53.264706  ...
# std     55.368689   82.390341  103.046215   140.827064   226.401744  ...
# ...

# %%
df.columns
# Out:
# Index(['Country of Birth', 'Total', '%', '1949', '1950', '1951', '1952',
#        '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
df = df.drop(labels=334, axis=0)
df
# Out:
#     Country of Birth  Total      %  1949  1950  1951  1952  1953  1954  1955  \
# 0               Aden     25  0.00%   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1        Afghanistan   3683  0.40%   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2            Albania    145  0.02%   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3            Algeria    247  0.03%   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     American Samoa    877  0.09%   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..               ...    ...    ...   ...   ...   ...   ...   ...   ...   ...
# 329       Yugoslavia   6441  0.69%  39.0  27.0  21.0  20.0  23.0  24.0  20.0
# 330            Zaire     25  0.00%   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 331           Zambia   1449  0.16%   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 332         Zanzibar      3  0.00%   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 333         Zimbabwe   8400  0.90%   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
df['1949'] = df.iloc[:,3:4].sum(axis=1)
df['1950-1959'] = df.iloc[:,4:14].sum(axis=1)
df['1960-1069'] = df.iloc[:,14:24].sum(axis=1)
df['1970-1979'] = df.iloc[:,24:34].sum(axis=1)
df['1980-1989'] = df.iloc[:,34:44].sum(axis=1)
df['1990-1999'] = df.iloc[:,44:54].sum(axis=1)
df['2000-2009'] = df.iloc[:,54:64].sum(axis=1)
df['2010-2020'] = df.iloc[:,64:75].sum(axis=1)

# %%
years = ['1949','1950-1959','1960-1069','1970-1979','1980-1989','1990-1999','2000-2009','2010-2020']
df.sort_values(['Total'], ascending=False, axis=0, inplace=True)
df_top5 = df.head()
df_top5.set_index('Country of Birth', inplace=True)
df_top5 = df_top5[years].transpose()
df_top5
# Out:
# Country of Birth  England    India  South Africa    China     Fiji
# 1949               9429.0    320.0         140.0     51.0    221.0
# 1950-1959          1596.0    409.0          51.0    458.0     85.0
# 1960-1069          2064.0   1019.0         856.0   1750.0    388.0
# 1970-1979         27979.0   1596.0        1143.0   1154.0   1448.0
# 1980-1989         49553.0   1715.0        1692.0   2150.0   2304.0
# 1990-1999         29735.0   6162.0        5830.0  16450.0  10928.0
# 2000-2009         24531.0  26180.0       23039.0  26560.0  14652.0
# 2010-2020         35808.0  32812.0       29981.0  10981.0  22824.0

# %%
df_top5.plot(kind='bar')

plt.title('Top 5 immigrants to NZ from 1949 to 2020')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
df_brazil = df.loc[df['Country of Birth']=='Brazil', years]

df_brazil= df_brazil[years].transpose()

df_brazil.plot(kind='bar')
plt.title('Brazilian immigrants to NZ from 1949 to 2020')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')
